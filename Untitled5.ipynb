# %% [markdown]
# <a href="https://colab.research.google.com/github/ssojjeong/Github/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from matplotlib import pyplot as plt

x = np.arange(0,3)
y = x**2 + np.sin(3*x+7)

plt.plot(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

def f(a,b):
	return a**2 + np.sin(2*b)

def grad_f(a,b):
  h=1e-5
  return [(f(a+h,b) - f(a-h,b))/(2*h),(f(a,b+h) - f(a,b-h))/(2*h)]


def gradient_descent(theta0, iters, alpha):
	history = [theta0]
	theta = theta0

	for i in range(iters):
		gradient = grad_f(theta[0],theta[1])
		theta = [a - alpha*b for a,b in zip(theta, gradient)]
		history.append(theta)
	return history

history = gradient_descent(theta0 = [-4, -4], iters =30, alpha = 0.05)

fig = plt.figure(figsize=(25, 10))
ax = fig.gca(projection='3d')

a = np.arange(-4, 4, 0.5)
b = np.arange(-4, 4, 0.5)
a, b = np.meshgrid(a, b)
c = f(a,b)
surf = ax.plot_surface(a, b, c, rstride=1, cstride=1, alpha=0.3, 
		 linewidth=0, antialiased=False, cmap='rainbow')


a = np.array([x[0] for x in history])
b = np.array([x[1] for x in history])
c =  f(a,b)

ax.scatter(a, b, c, color="b"); 

print(c)


plt.xlabel('Feature A')
plt.ylabel('Feature B')


plt.show()
# Out:
# [15.01064175 11.96682717  9.50197615  7.50585952  5.88927075  4.58000456
#   3.51960847  2.66075784  1.9651338   1.40170714  0.94534998  0.57571249
#   0.27631368  0.03380548 -0.16262306 -0.32172821 -0.4506021  -0.55498914
#  -0.63954213 -0.70802972 -0.76350445 -0.80843885 -0.84483562 -0.87431695
#  -0.89819679 -0.91753944 -0.93320698 -0.94589767 -0.95617712 -0.96450347
#  -0.97124782]

# %%
import seaborn as sns
import pandas as pd

drinksData = pd.read_csv('https://raw.githubusercontent.com/ssojjeong/drink/main/caffeine.csv')

sns.set_theme()
sns.set(rc={"figure.dpi":300})
sns.set(rc={"figure.figsize":(6,3)})

sns.scatterplot(x="Calories", y="Caffeine (mg)", data=drinksData, hue ='type')

# %%
sns.histplot(y="Calories", data=drinksData)

# %%
sns.histplot(x="Caffeine (mg)",data=drinksData, hue="type")

# %%
sns.barplot(x="type", y="Calories", data=drinksData)

# %%
sns.boxplot("type", y="Caffeine (mg)", data=drinksData)
